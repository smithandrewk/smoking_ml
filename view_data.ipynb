# %%
import pandas as pd
import os
# seems like reverse chronological order but not sure
dir = f'files'
files = os.listdir(f'{dir}')
filename = f'{dir}/{files[0]}'
print(filename)
# Out:
# files/2010-01-06_22_02_10.csv

# %%
df = pd.read_csv(filename,header=None)
df[0] = df[0]*1e-9
df[0] = df[0] - df[0][0]
df = df.reset_index()

# %%
df[0].diff().sum()
# Out:
# 342.87880000000587

# %%
len(df)/(df[0].diff().sum())
# Out:
# 19.96623879924884

# %%
import numpy as np
line = np.linspace(0,342.8788,6846)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.lineplot(data=df,x=0,y='index')
plt.plot(df[0],line)

# %%
(df[0].diff()*1000).plot()
df[0].plot()
df
# Out:
# <AxesSubplot:>

# %%
df[0].plot()
# Out:
# <AxesSubplot:>

# %%
(df[0][1500:1600]*1e-9).diff()
# Out:
# 1500       NaN
# 1501    0.0000
# 1502    0.0303
# 1503    0.0000
# 1504    0.0000
#          ...
# 1595    0.0000
# 1596    0.0202
# 1597    0.0101
# 1598    0.0000
# 1599    0.0202
# Name: 0, Length: 100, dtype: float64

# %%
(df[0][1500:1600]*1e-9).diff().plot()
# Out:
# <AxesSubplot:>

# %%
df[0].diff().plot()
# Out:
# <AxesSubplot:>

# %%
import plotly.express as px
fig = px.line(df,y=['acc_x','acc_y','acc_z'])
fig.show(renderer='browser')

# %%
df = pd.read_csv(f'~/database-name.csv')
df.timestamp.diff()[3100:].plot()
# Out:
# <AxesSubplot:>
